# %%
import pandas as pd

# %%
df= pd.read_csv("traffic_accidents.csv")

# %%
df
# Out:
#                     crash_date traffic_control_device weather_condition  \
# 0       07/29/2023 01:00:00 PM         TRAFFIC SIGNAL             CLEAR
# 1       08/13/2023 12:11:00 AM         TRAFFIC SIGNAL             CLEAR
# 2             12-09-2021 10:30         TRAFFIC SIGNAL             CLEAR
# 3             08-09-2023 19:55         TRAFFIC SIGNAL             CLEAR
# 4       08/19/2023 02:55:00 PM         TRAFFIC SIGNAL             CLEAR
# ...                        ...                    ...               ...
# 209301  09/13/2023 01:08:00 PM                UNKNOWN           UNKNOWN
# 209302  07/18/2023 02:10:00 PM                UNKNOWN             CLEAR
# 209303  10/23/2019 01:32:00 PM         TRAFFIC SIGNAL             CLEAR
# 209304        06-01-2020 15:23            NO CONTROLS             CLEAR
# 209305  12/16/2022 12:10:00 PM         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209306 entries, 0 to 209305
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_date                     209306 non-null  object
#  1   traffic_control_device         209306 non-null  object
#  2   weather_condition              209306 non-null  object
#  3   lighting_condition             209306 non-null  object
#  4   first_crash_type               209306 non-null  object
#  5   trafficway_type                209306 non-null  object
#  6   alignment                      209306 non-null  object
#  7   roadway_surface_cond           209306 non-null  object
#  8   road_defect                    209306 non-null  object
#  9   crash_type                     209306 non-null  object
#  10  intersection_related_i         209306 non-null  object
#  11  damage                         209306 non-null  object
# ...

# %%
df.shape
# Out:
# (209306, 24)

# %%
df.describe()
# Out:
#            num_units  injuries_total  injuries_fatal  injuries_incapacitating  \
# count  209306.000000   209306.000000   209306.000000            209306.000000
# mean        2.063300        0.382717        0.001859                 0.038102
# std         0.396012        0.799720        0.047502                 0.233964
# min         1.000000        0.000000        0.000000                 0.000000
# 25%         2.000000        0.000000        0.000000                 0.000000
# 50%         2.000000        0.000000        0.000000                 0.000000
# 75%         2.000000        1.000000        0.000000                 0.000000
# max        11.000000       21.000000        3.000000                 7.000000
#
#        injuries_non_incapacitating  injuries_reported_not_evident  \
# count                209306.000000                  209306.000000
# mean                      0.221241                       0.121516
# std                       0.614960                       0.450865
# ...

# %%
nulls=df.isnull().sum()
nulls
# Out:
# crash_date                       0
# traffic_control_device           0
# weather_condition                0
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_i           0
# damage                           0
# prim_contributory_cause          0
# num_units                        0
# most_severe_injury               0
# injuries_total                   0
# injuries_fatal                   0
# injuries_incapacitating          0
# injuries_non_incapacitating      0
# injuries_reported_not_evident    0
# injuries_no_indication           0
# crash_hour                       0
# crash_day_of_week                0
# crash_month                      0
# dtype: int64

# %%
df["crash_date"]=pd.to_datetime(df["crash_date"],format="mixed",dayfirst=True)

# %%
# Create two new columns
df['date'] = df['crash_date'].dt.date 
df['time'] = df['crash_date'].dt.time 
df
# Out:
#                 crash_date traffic_control_device weather_condition  \
# 0      2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1      2023-08-13 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2      2021-09-12 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3      2023-09-08 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4      2023-08-19 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                    ...                    ...               ...
# 209301 2023-09-13 13:08:00                UNKNOWN           UNKNOWN
# 209302 2023-07-18 14:10:00                UNKNOWN             CLEAR
# 209303 2019-10-23 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304 2020-01-06 15:23:00            NO CONTROLS             CLEAR
# 209305 2022-12-16 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
print(df[['crash_date', 'date', 'time']].head())
# Out:
#            crash_date        date      time
# 0 2023-07-29 13:00:00  2023-07-29  13:00:00
# 1 2023-08-13 00:11:00  2023-08-13  00:11:00
# 2 2021-09-12 10:30:00  2021-09-12  10:30:00
# 3 2023-09-08 19:55:00  2023-09-08  19:55:00
# 4 2023-08-19 14:55:00  2023-08-19  14:55:00

# %%
df["crash_month"]=df["crash_date"].dt.month
df
# Out:
#                 crash_date traffic_control_device weather_condition  \
# 0      2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1      2023-08-13 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2      2021-09-12 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3      2023-09-08 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4      2023-08-19 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                    ...                    ...               ...
# 209301 2023-09-13 13:08:00                UNKNOWN           UNKNOWN
# 209302 2023-07-18 14:10:00                UNKNOWN             CLEAR
# 209303 2019-10-23 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304 2020-01-06 15:23:00            NO CONTROLS             CLEAR
# 209305 2022-12-16 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df
# Out:
#                 crash_date traffic_control_device weather_condition  \
# 0      2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1      2023-08-13 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2      2021-09-12 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3      2023-09-08 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4      2023-08-19 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                    ...                    ...               ...
# 209301 2023-09-13 13:08:00                UNKNOWN           UNKNOWN
# 209302 2023-07-18 14:10:00                UNKNOWN             CLEAR
# 209303 2019-10-23 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304 2020-01-06 15:23:00            NO CONTROLS             CLEAR
# 209305 2022-12-16 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df.columns
# Out:
# Index(['crash_date', 'traffic_control_device', 'weather_condition',
#        'lighting_condition', 'first_crash_type', 'trafficway_type',
#        'alignment', 'roadway_surface_cond', 'road_defect', 'crash_type',
#        'intersection_related_i', 'damage', 'prim_contributory_cause',
#        'num_units', 'most_severe_injury', 'injuries_total', 'injuries_fatal',
#        'injuries_incapacitating', 'injuries_non_incapacitating',
#        'injuries_reported_not_evident', 'injuries_no_indication', 'crash_hour',
#        'crash_day_of_week', 'crash_month', 'date', 'time'],
#       dtype='object')

# %%
print(df.iloc[:, -5:].head())
# Out:
#    crash_hour  crash_day_of_week  crash_month        date      time
# 0          13                  7            7  2023-07-29  13:00:00
# 1           0                  1            8  2023-08-13  00:11:00
# 2          10                  5            9  2021-09-12  10:30:00
# 3          19                  4            9  2023-09-08  19:55:00
# 4          14                  7            8  2023-08-19  14:55:00

# %%
df['crash_day_of_week'] = df['crash_date'].dt.day_name()

# %%
df.crash_day_of_week
# Out:
# 0          Saturday
# 1            Sunday
# 2            Sunday
# 3            Friday
# 4          Saturday
#             ...
# 209301    Wednesday
# 209302      Tuesday
# 209303    Wednesday
# 209304       Monday
# 209305       Friday
# Name: crash_day_of_week, Length: 209306, dtype: object

# %%
df
# Out:
#                 crash_date traffic_control_device weather_condition  \
# 0      2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1      2023-08-13 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2      2021-09-12 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3      2023-09-08 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4      2023-08-19 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                    ...                    ...               ...
# 209301 2023-09-13 13:08:00                UNKNOWN           UNKNOWN
# 209302 2023-07-18 14:10:00                UNKNOWN             CLEAR
# 209303 2019-10-23 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304 2020-01-06 15:23:00            NO CONTROLS             CLEAR
# 209305 2022-12-16 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df.rename(columns={'crash_date':'crash_date_and_time'})
# Out:
#             crash_date_and_time traffic_control_device weather_condition  \
# 0       29-07-2023 Jul:00:00 PM         TRAFFIC SIGNAL             CLEAR
# 1       13-08-2023 Aug:11:00 AM         TRAFFIC SIGNAL             CLEAR
# 2       12-09-2021 Sep:30:00 AM         TRAFFIC SIGNAL             CLEAR
# 3       08-09-2023 Sep:55:00 PM         TRAFFIC SIGNAL             CLEAR
# 4       19-08-2023 Aug:55:00 PM         TRAFFIC SIGNAL             CLEAR
# ...                         ...                    ...               ...
# 209301  13-09-2023 Sep:08:00 PM                UNKNOWN           UNKNOWN
# 209302  18-07-2023 Jul:10:00 PM                UNKNOWN             CLEAR
# 209303  23-10-2019 Oct:32:00 PM         TRAFFIC SIGNAL             CLEAR
# 209304  06-01-2020 Jan:23:00 PM            NO CONTROLS             CLEAR
# 209305  16-12-2022 Dec:10:00 PM         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# ...

# %%
df["crash_date"] = pd.to_datetime(df["crash_date"],format="mixed")
df["crash_date"] = df["crash_date"].dt.strftime("%d-%m-%Y %I:%M:%S %p")

# %%
df
# Out:
#                     crash_date traffic_control_device weather_condition  \
# 0       29-07-2023 01:00:00 PM         TRAFFIC SIGNAL             CLEAR
# 1       13-08-2023 12:11:00 AM         TRAFFIC SIGNAL             CLEAR
# 2       12-09-2021 10:30:00 AM         TRAFFIC SIGNAL             CLEAR
# 3       08-09-2023 07:55:00 PM         TRAFFIC SIGNAL             CLEAR
# 4       19-08-2023 02:55:00 PM         TRAFFIC SIGNAL             CLEAR
# ...                        ...                    ...               ...
# 209301  13-09-2023 01:08:00 PM                UNKNOWN           UNKNOWN
# 209302  18-07-2023 02:10:00 PM                UNKNOWN             CLEAR
# 209303  23-10-2019 01:32:00 PM         TRAFFIC SIGNAL             CLEAR
# 209304  06-01-2020 03:23:00 PM            NO CONTROLS             CLEAR
# 209305  16-12-2022 12:10:00 PM         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# ...

# %%
month_map = {
    1: "January", 2: "February", 3: "March", 4: "April",
    5: "May", 6: "June", 7: "July", 8: "August",
    9: "September", 10: "October", 11: "November", 12: "December"
}

# Apply mapping
df['crash_month'] = df['crash_month'].map(month_map)

# %%
df
# Out:
#                 crash_date traffic_control_device weather_condition  \
# 0      2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1      2023-08-13 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2      2021-09-12 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3      2023-09-08 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4      2023-08-19 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                    ...                    ...               ...
# 209301 2023-09-13 13:08:00                UNKNOWN           UNKNOWN
# 209302 2023-07-18 14:10:00                UNKNOWN             CLEAR
# 209303 2019-10-23 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304 2020-01-06 15:23:00            NO CONTROLS             CLEAR
# 209305 2022-12-16 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df["crash_date"] = pd.to_datetime(df["crash_date"],format="mixed")
df["crash_date"] = df["crash_date"].dt.strftime("%d-%m-%Y %I:%M:%S %p")

# %%
df

# %%
df["time"]=pd.to_datetime(df["time"],format= "%H:%M:%S").dt.strftime("%H:%M")
df

# %%
df

# %%
df["date"]=pd.to_datetime(df["date"],format="mixed")
df["date"]=df["date"].dt.strftime("%d-%m-%Y")
df
# Out:
#                  crash_date traffic_control_device weather_condition  \
# 0       29-07-2023 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1       13-08-2023 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2       12-09-2021 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3       08-09-2023 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4       19-08-2023 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                     ...                    ...               ...
# 209301  13-09-2023 13:08:00                UNKNOWN           UNKNOWN
# 209302  18-07-2023 14:10:00                UNKNOWN             CLEAR
# 209303  23-10-2019 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304  06-01-2020 15:23:00            NO CONTROLS             CLEAR
# 209305  16-12-2022 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df["crash_date"] = pd.to_datetime(df["crash_date"], dayfirst=True, errors="coerce")
df["Year"]=df["crash_date"].dt.year

# %%
df
# Out:
#                 crash_date traffic_control_device weather_condition  \
# 0      2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# 1      2023-08-13 00:11:00         TRAFFIC SIGNAL             CLEAR
# 2      2021-09-12 10:30:00         TRAFFIC SIGNAL             CLEAR
# 3      2023-09-08 19:55:00         TRAFFIC SIGNAL             CLEAR
# 4      2023-08-19 14:55:00         TRAFFIC SIGNAL             CLEAR
# ...                    ...                    ...               ...
# 209301 2023-09-13 13:08:00                UNKNOWN           UNKNOWN
# 209302 2023-07-18 14:10:00                UNKNOWN             CLEAR
# 209303 2019-10-23 13:32:00         TRAFFIC SIGNAL             CLEAR
# 209304 2020-01-06 15:23:00            NO CONTROLS             CLEAR
# 209305 2022-12-16 12:10:00         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df.to_csv("traffic_accidents_python.csv",index=False)
